# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os 
import sys
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
sns.set_theme()

pd.options.display.float_format='{:.4f}'.format
plt.rcParams['figure.figsize'] = [8,8]
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500) 
sns.set(style='darkgrid')
# %matplotlib inline

filename3 = os.path.join(os.getcwd(), "MASTER_DATASET.csv")
df = pd.read_csv(filename3, header=0)

# %%
df.describe()
# Out:
#        # total population  # female population  # male population  \
# count            525.0000             525.0000           525.0000
# mean         1658112.1257          879628.7600        760279.1600
# std           848318.2447          442037.6503        370538.8201
# min           433000.0000          468777.0000        414272.0000
# 25%          1033580.0000          558993.0000        480903.0000
# 50%          1250000.0000          655503.0000        597084.0000
# 75%          2098324.0000         1136515.0000        961809.0000
# max          4272000.0000         2207252.0000       1839235.0000
#
#        # female younger population (0 - 14 years)  \
# count                                    525.0000
# mean                                  118611.7600
# std                                    52314.2548
# min                                    61356.0000
# 25%                                    76623.0000
# 50%                                    95205.0000
# ...

# %%
df1 = df.drop(columns = ['oblast_or_country','pcode','period'])
plt.figure(figsize = (40,20))        
ax = sns.heatmap(df1.corr(),annot = True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 1, top - 1)
# Out:
# (32.0, -1.0)

# %%
df.head()
# Out:
#   oblast_or_country pcode  # total population  # female population  \
# 0         Cherkaska  UA71             1157115               624475
# 1      Chernihivska  UA74              950773               518447
# 2      Chernivetska  UA73              887392               468777
# 3   Dnipropetrovska  UA12             3093176              1680750
# 4          Donetska  UA14             4046487              2207252
#
#    # male population  # female younger population (0 - 14 years)  \
# 0             532640                                       75552
# 1             432326                                       61356
# 2             418615                                       73482
# 3            1412426                                      226943
# 4            1839235                                      204708
#
#    # male younger population (0 - 14 years)  \
# 0                                     81536
# 1                                     64084
# ...

# %%
#Not able to drop columns that have km^2 metrics therefore hindering the ability to look at specifc correlations between features.
